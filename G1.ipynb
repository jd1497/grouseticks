# %%
library(lme4)

data(grouseticks)
## Figure 1a from Elston et al
par(las=1,bty="l")
tvec <- c(0,1,2,5,20,40,80)
pvec <- c(4,1,3)
with(grouseticks_agg,plot(1+meanTICKS~HEIGHT,
                  pch=pvec[factor(YEAR)],
                  log="y",axes=FALSE,
                  xlab="Altitude (m)",
                  ylab="Brood mean ticks"))
axis(side=1)
axis(side=2,at=tvec+1,label=tvec)
box()
abline(v=405,lty=2)
## Figure 1b
with(grouseticks_agg,plot(varTICKS~meanTICKS,
                  pch=4,
                  xlab="Brood mean ticks",
                  ylab="Within-brood variance"))
curve(1*x,from=0,to=70,add=TRUE)
## Model fitting
form <- TICKS~YEAR+HEIGHT+(1|BROOD)+(1|INDEX)+(1|LOCATION)
(full_mod1  <- glmer(form, family="poisson",data=grouseticks))
# Out:
# Warning message:
# "package 'lme4' was built under R version 3.4.4"Loading required package: Matrix
# Warning message:
# "package 'Matrix' was built under R version 3.4.4"
# plot without title
# Warning message in checkConv(attr(opt, "derivs"), opt$par, ctrl = control$checkConv, :
# "Model failed to converge with max|grad| = 0.0048111 (tol = 0.001, component 1)"Warning message in checkConv(attr(opt, "derivs"), opt$par, ctrl = control$checkConv, :
# "Model is nearly unidentifiable: very large eigenvalue
#  - Rescale variables?;Model is nearly unidentifiable: large eigenvalue ratio
#  - Rescale variables?"
# Generalized linear mixed model fit by maximum likelihood (Laplace
#   Approximation) [glmerMod]
#  Family: poisson  ( log )
# Formula: TICKS ~ YEAR + HEIGHT + (1 | BROOD) + (1 | INDEX) + (1 | LOCATION)
#    Data: grouseticks
#       AIC       BIC    logLik  deviance  df.resid
# 1794.5427 1822.5353 -890.2714 1780.5427       396
# Random effects:
#  Groups   Name        Std.Dev.
#  INDEX    (Intercept) 0.5415
#  BROOD    (Intercept) 0.7500
#  LOCATION (Intercept) 0.5287
# Number of obs: 403, groups:  INDEX, 403; BROOD, 118; LOCATION, 63
# Fixed Effects:
# (Intercept)       YEAR96       YEAR97       HEIGHT
#    11.35582      1.18041     -0.97869     -0.02376
# convergence code 0; 3 optimizer warnings; 0 lme4 warnings
# plot without title

# %%
data(grouseticks)
## Figure 1a from Elston et al
par(las=1,bty="l")
tvec <- c(0,1,2,5,20,40,80)
pvec <- c(4,1,3)
with(grouseticks_agg,plot(1+meanTICKS~HEIGHT,
                          pch=pvec[factor(YEAR)],
                          log="y",axes=FALSE,
                          xlab="Altitude (m)",
                          ylab="Brood mean ticks"))

axis(side=1)
axis(side=2,at=tvec+1,label=tvec)
box()
abline(v=405,lty=2)

## Figure 1b
with(grouseticks_agg,plot(varTICKS~meanTICKS,
                          pch=4,xlab="Brood mean ticks",
                          ylab="Within-brood variance"))
curve(1*x,from=0,to=70,add=TRUE)
# Out:
# plot without title
# plot without title

# %%
## Model fitting
form <- TICKS~YEAR+HEIGHT+(1|BROOD)+(1|INDEX)+(1|LOCATION)
(full_mod1  <- glmer(form, family="poisson",data=grouseticks))
# Out:
# Warning message in checkConv(attr(opt, "derivs"), opt$par, ctrl = control$checkConv, :
# "Model failed to converge with max|grad| = 0.0048111 (tol = 0.001, component 1)"Warning message in checkConv(attr(opt, "derivs"), opt$par, ctrl = control$checkConv, :
# "Model is nearly unidentifiable: very large eigenvalue
#  - Rescale variables?;Model is nearly unidentifiable: large eigenvalue ratio
#  - Rescale variables?"
# Generalized linear mixed model fit by maximum likelihood (Laplace
#   Approximation) [glmerMod]
#  Family: poisson  ( log )
# Formula: TICKS ~ YEAR + HEIGHT + (1 | BROOD) + (1 | INDEX) + (1 | LOCATION)
#    Data: grouseticks
#       AIC       BIC    logLik  deviance  df.resid
# 1794.5427 1822.5353 -890.2714 1780.5427       396
# Random effects:
#  Groups   Name        Std.Dev.
#  INDEX    (Intercept) 0.5415
#  BROOD    (Intercept) 0.7500
#  LOCATION (Intercept) 0.5287
# Number of obs: 403, groups:  INDEX, 403; BROOD, 118; LOCATION, 63
# Fixed Effects:
# (Intercept)       YEAR96       YEAR97       HEIGHT
#    11.35582      1.18041     -0.97869     -0.02376
# convergence code 0; 3 optimizer warnings; 0 lme4 warnings
